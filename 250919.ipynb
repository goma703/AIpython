# %%
name='홍길동'
age=18

# %%
name='홍길동'
age=18
print(age)
# Out:
# 18

# %%
print(name)
# Out:
# 홍길동

# %%
c=10

# %%
b=c

# %%
a=b

# %%
print(a,b,c)
# Out:
# 10 10 10

# %%
you_age=100

# %%
age=10

# %%
AGE=100

# %%
age
# Out:
# 10

# %%
a=11
b=7
c=a
a=b
b=c

# %%
multiples_of_3 = []
current_multiple = 0
count = 0

while count < 5:
    current_multiple += 3
    multiples_of_3.append(current_multiple)
    count += 1

print("3의 배수 중 처음 4개:", multiples_of_3)
# Out:
# 3의 배수 중 처음 4개: [3, 6, 9, 12, 15]

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
height=180.5

# %%
type(height)
# Out:
# float

# %%
flag=True

# %%
type(flag)
# Out:
# bool

# %%
a=20
b=0o34
c=0xA1
d=0b1110

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 20
# 28
# 161
# 14

# %%
a=10
b=20

# %%
c,d=30,40

# %%
a
# Out:
# 10

# %%
c
# Out:
# 30

# %%
d
# Out:
# 40

# %%
a=10>20

# %%
a
# Out:
# False

# %%
type(a)
# Out:
# bool

# %%
a="Python"

# %%
a
# Out:
# 'Python'

# %%
a="Hi!"+"Python"

# %%
a
# Out:
# 'Hi!Python'

# %%
a=10
b='10'

# %%
c=str(a)+b
c
# Out:
# '1010'

# %%
o=a+float(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-752045005.py in <cell line: 0>()
# ----> 1 o=a+float(b)
#
# TypeError: can only concatenate str (not "float") to str

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# str

# %%
age+=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3256244110.py in <cell line: 0>()
# ----> 1 age+=2
#
# TypeError: can only concatenate str (not "int") to str

# %%
name(input('이름을 입력'))
age(input('나이를 입력'))
# Out:
# 이름을 입력홍길동
# 나이를 입력18

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# str

# %%
type(age)
# Out:
# str

# %%
a=int(input())
b=int(input())
o=a-b
print(a,b,o)
print(a)
print()
print(b)
print(o)
# Out:
# 9
# 5
# 9 5 4
# 9
#
# 5
# 4

# %%
print(int(5)**2*3.14)
# Out:
# 78.5

# %%
int(input()**2*3.14)
# Out:
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2769689800.py in <cell line: 0>()
# ----> 1 int(input()**2*3.14)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
new_var = print(int(input())**2*3.14)
# Out:
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2769689800.py in <cell line: 0>()
# ----> 1 int(input()**2*3.14)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
print(int(input())**2*3.14)
# Out:
# 9
# 254.34
